# %%
import pandas as pd
insurance_df=pd.read_csv('/Volumes/python_catelog/classs_schema/insurance_data/insurance.csv')
print(insurance_df)

#/Volumes/python_catelog/classs_schema/insurance_data/insurance.csv
