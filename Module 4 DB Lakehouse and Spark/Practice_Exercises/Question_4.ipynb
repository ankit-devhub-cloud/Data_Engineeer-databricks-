# %% [markdown]
# ### Find all periods of 3 or more consecutive days where the temperature stayed below 0°C.

# %%
days_temp = [('2025-01-01',2),('2025-01-02',-2),('2025-01-03',-2),('2025-01-04',-2),('2025-01-05',-1),('2025-01-06',0),('2025-01-07',2),('2025-01-08',2)]
columns = ["date", "temperature"]

df = spark.createDataFrame(days_temp, columns)
df.show()
