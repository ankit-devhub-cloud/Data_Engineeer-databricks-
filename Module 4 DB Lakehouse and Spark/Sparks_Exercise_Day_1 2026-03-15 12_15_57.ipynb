# %%
from pyspark.sql import SparkSession
 
spark = SparkSession.builder \
    .appName("CSV Learning Session") \
    .getOrCreate()

# %%
print(spark)

# %%
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv")

df.show()

# %%
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv",header = True)

display(df)

# %%
df.describe().show()

# %%
df.printSchema()

# %%
df.head(2)

# %%
df.write.format("csv").mode('overwrite').save("/Volumes/ecommerceonline/shopping/sales_store/output_csv/")

# %%
df.write.format("parquet").mode("overwrite").save("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv/sales_parquet.parquet")

# %%
df.repartition(1).write.format("parquet").mode("overwrite").save("/Volumes/ecommerceonline/shopping/sales_store/output_parquet/")
