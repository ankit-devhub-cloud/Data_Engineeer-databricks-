# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D1").getOrCreate()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D2").getOrCreate()
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv", header=True, inferSchema=True)

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D2").getOrCreate()
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv", header=True, inferSchema=True) 
df.display()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D2").getOrCreate()
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv", header=True, inferSchema=True) 
df.printSchema()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D2").getOrCreate()
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv", header=True, inferSchema=True) 

df.select("Order ID", "Customer Name", "Product ID",Q).show()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercises_D2").getOrCreate()
df = spark.read.csv("/Volumes/ecommerceonline/shopping/sales_store/Sample - Superstore.csv", header=True, inferSchema=True) 

df.show()

# %%
df_graterthan= df.where(df.Quantity >3)
display(df_graterthan)
