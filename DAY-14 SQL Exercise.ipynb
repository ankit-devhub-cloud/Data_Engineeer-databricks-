# %% [markdown]
# Databricks SQL Job Exercises Using netflix.csv

# %%
# %sql
create catalog if not Exists OTT_Platform;

# %%
# %sql
Create Schema if not exists OTT_platform.Netflix_OTT;

# %%
# %sql
use catalog OTT_platform;
Use Schema Netflix_OTT;

# %%
# %sql
Select* FROM OTT_platform.Netflix_OTT.netflix;

# %%
# %sql
Select  Name,Year,`Age Rating`, Duration, Category
from OTT_platform.Netflix_OTT.netflix;

# %%
# %sql
Select * 
from OTT_Platform.Netflix_OTT.netflix
Where Values is not null;
